# %% [markdown]
# # **[作業目標]**
#
#
#
#
# 持續接觸有關機器學習的相關專案與最新技術

# %% [markdown]
# # **[作業重點]**
#
# 透過觀察頂尖公司的機器學習文章，來了解各公司是怎麼應用機器學習在實際的專案上

# %% [markdown]
# # **[作業]**

# %% [markdown]
# ###**目標**
# 利用pixels創建可提取利用的metadata給手機應用程式做UI的提升

# %% [markdown]
# ###**方法**
# 使用最常在物件偵測上用的Non-Maximum Suppression (NMS)

# %% [markdown]
# ###**資料來源**
#
# ![擷取.PNG](data:image/png;base64,...)
#
#
# (i) collecting the screens, in which we captured
# screenshots and extracted information of their UI trees and accessibility trees
#
#
# (ii) manually annotating the visual UI elements on the screens.
